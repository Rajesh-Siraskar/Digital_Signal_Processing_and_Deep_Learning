# %% [markdown]
# # Deep Learning for Audio Signals
#
# ### Training a CNN on MFCC features generated from Genre music files
#
# Rajesh Siraskar | 04-May-2021
#
# - Load data
# - Create train/validation/test sets (unseen)
# - Build CNN network architecture
# - Compile network
# - Train network
# - Evaluate
# - Make predictions on a sample

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
# %matplotlib inline

# %%
JSON_DATA_FILE = "audio_files/mfcc_json.json"
NUMBER_OF_CLASSES = 4 # Reduced set has only 4 genres

# %% [markdown]
# ### Load data

# %%
def load_data(json_file):
    with open(json_file, "r") as fp:
        data = json.load(fp)
        
        # Note: mfcc was converted from a numpy array to list before storing in JSON
        #  Need convert back to numpy array
        X = np.array(data["mfcc"])
        y = np.array(data["labels"])
        
    return X, y

# %% [markdown]
# ### 1. Create train/validation/test sets (unseen)
# --------------------------------------------------------
#
# #### Note: CNN expects a 3-D array.
#     - Our data was saved with the following parameters
#     - num_mfcc=13; num_segments=10; num_mfcc_vectors_per_segment: 130
#     - X.data.shape:  (80, 130, 13)
#     - y.data.shape:  (80,)
#
#     - X.data.shape: dim-1: No of samples = 4 classes * 2 .wav files per genre * 10 segments = 80,
#     -               dim-2: time-bins = 130,
#     -               dim-3: mfcc-features = 13)
#
# ### For CNN we need to add an additional channel:
#     - Loaded X is (80, 130, 1)
#     - For CNN, X needs to be (130, 13, 1)
#     - The 3rd dim is the CHANNEL so will be 1
#     - So X becomes actually a 4D arraay with the added channel dim

# %%
def prepare_datasets(test_size=0.25, validation_size=0.2):
    # load data
    X, y = load_data(JSON_DATA_FILE)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    # create train/validation set
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, 
                                                                    test_size=validation_size)
    
    # CNN expects a 3-D array
    # -----------------------
    # Our data was saved with the following parameters
    #    num_mfcc=13; num_segments=10; num_mfcc_vectors_per_segment: 130
    # X.data.shape: dim-1: No of samples = 4 classes * 2 .wav files per genre * 10 segments = 80, 
    #               dim-2: time-bins = 130, 
    #               dim-3: mfcc-features = 13)
    # y.data.shape:  (80,)
    #
    #
    # For CNN we need to add an additional channel: 
    # - Loaded X is (80, 130, 1)
    # - For CNN, X needs to be (130, 13, 1)
    # - The 3rd dim is the CHANNEL so will be 1
    # - So X becomes actually a 4D arraay with the added channel dim
    
    # Create the 3-D array for X_train, but first add newaxis for channel
    X_train = X_train [..., np.newaxis]           # 4D array = [num_sample, 130, 13, 1]
    X_validation = X_validation [..., np.newaxis] # -- "" --
    X_test = X_test [..., np.newaxis]             # -- "" --
    
    # Return the 4-D data
    return  X_train, X_validation, X_test, y_train, y_validation, y_test

# %% [markdown]
# ### 2. Build the CNN network

# %%
def build_model(input_shape):
    
    # Ceate model
    model = keras.Sequential()
    # 1st conv. layer (along with max-pooling,normalize output - which speeds up training)
    model.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', 
                                  input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'))
    model.add(keras.layers.BatchNormalization())              
    
    # 2nd. conv. layer - same as above. Note input shape remains same
    model.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', 
                                  input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'))
    model.add(keras.layers.BatchNormalization())                      
    
    # 3rd. conv. layer - same as above but reduce filter sizes (both kernel and pooling)
    # Again, note, input shape remains same
    model.add(keras.layers.Conv2D(filters=32, kernel_size=(2,2), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((2,2), strides=(2,2), padding='same'))
    model.add(keras.layers.BatchNormalization()) 
    
    # Flatten the output and feed to a dense layer, also add dropout to reduce over-fitting
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))
    
    # Final output layer with softmax) for classification
    # Neurons = number of classes i.e. genres = NUMBER_OF_CLASSES
    model.add(keras.layers.Dense(NUMBER_OF_CLASSES, activation='softmax'))
    
    return model

# %% [markdown]
# ### Utility functions:
# 1. Plot accuracy/loss curves
# 2. Load JSON data file and return genre names

# %%
def plot_history (history, regularization_flag=False):

    fig, axs = plt.subplots(2, figsize=(12, 8)) # width, height
    
    # Accuracy sub-plot
    axs[0].plot(history.history["accuracy"], label="Training accuracy")
    axs[0].plot(history.history["val_accuracy"], label="Test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_facecolor('#FFFFF0') # little darker biege: #F5F5DC
    if regularization_flag: axs[0].set_title("Accuracy plot (with regularizatiton)")
    else: axs[0].set_title("Accuracy plot")
    
    # Error (loss) sub-plot
    axs[1].plot(history.history["loss"], label="Training error")
    axs[1].plot(history.history["val_loss"], label="Test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epochs")   
    axs[1].legend(loc="upper right")
    axs[1].set_facecolor('#FFFFF0')
    if regularization_flag: axs[1].set_title("Error plot (with regularizatiton)")
    else: axs[1].set_title("Error plot")
    

    plt.show()
    
def load_mappings(json_file):
    with open(json_file, "r") as fp:
        data = json.load(fp)
        
        # Note: mfcc was converted from a numpy array to list before storing in JSON
        #  Need convert back to numpy array
        genre_mapping = np.array(data["mapping"])
        
    return genre_mapping

# %% [markdown]
# ### Main function
# 1. Create train/validation/test sets (unseen)
# 2. Build the CNN network
# 3. Compile the network
# 4. Train the model
# 5. Evaluate the model on unseen test set
# 6. Predict on a sample

# %%
## 1. Create train/validation/test sets (unseen)
X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(test_size=0.25, 
                                                                                validation_size=0.2)
## 2. Build the CNN network
#  X_train is a 4-D array. For input shape, take the 3-dims from dimension 2 onwards. 
#  The 1st dim was num_samples and is not considered as it will be part of training samples
input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
model = build_model(input_shape)

## 3. Compile the network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

## 4. Train the model
history = model.fit(X_train, y_train, 
                    validation_data=(X_validation, y_validation), 
                    batch_size=32, 
                    epochs=200) # 30 epochs accuracy=0.70; 400 epochs=0.95

## 5. Evaluate the model on unseen test set
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1) 
print("\n\n - Accuracy on un-seen test set: {0:.3f}".format(test_accuracy))
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 262ms/step - loss: 2.1222 - accuracy: 0.2535 - val_loss: 3.5711 - val_accuracy: 0.3333
# Epoch 2/200
# 2/2 [==============================] - 0s 61ms/step - loss: 1.9506 - accuracy: 0.2812 - val_loss: 3.0337 - val_accuracy: 0.3333
# Epoch 3/200
# 2/2 [==============================] - 0s 57ms/step - loss: 2.0564 - accuracy: 0.2847 - val_loss: 2.7043 - val_accuracy: 0.3333
# Epoch 4/200
# 2/2 [==============================] - 0s 63ms/step - loss: 1.7694 - accuracy: 0.3438 - val_loss: 2.4683 - val_accuracy: 0.3333
# Epoch 5/200
# 2/2 [==============================] - 0s 58ms/step - loss: 1.6699 - accuracy: 0.3299 - val_loss: 2.2588 - val_accuracy: 0.3333
# Epoch 6/200
# 2/2 [==============================] - 0s 60ms/step - loss: 1.4992 - accuracy: 0.3611 - val_loss: 2.0873 - val_accuracy: 0.3333
# Epoch 7/200
# 2/2 [==============================] - 0s 61ms/step - loss: 1.2910 - accuracy: 0.3819 - val_loss: 1.9449 - val_accuracy: 0.3333
# Epoch 8/200
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1989 - accuracy: 0.5972 - val_loss: 1.8278 - val_accuracy: 0.3333
# Epoch 9/200
# 2/2 [==============================] - 0s 61ms/step - loss: 1.2802 - accuracy: 0.5208 - val_loss: 1.7213 - val_accuracy: 0.4167
# Epoch 10/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8360 - accuracy: 0.6875 - val_loss: 1.6318 - val_accuracy: 0.4167
# Epoch 11/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.9574 - accuracy: 0.6181 - val_loss: 1.5622 - val_accuracy: 0.4167
# Epoch 12/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.7196 - accuracy: 0.6875 - val_loss: 1.5059 - val_accuracy: 0.4167
# Epoch 13/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.8408 - accuracy: 0.6493 - val_loss: 1.4619 - val_accuracy: 0.4167
# Epoch 14/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.7014 - accuracy: 0.7465 - val_loss: 1.4220 - val_accuracy: 0.4167
# Epoch 15/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.7434 - accuracy: 0.7396 - val_loss: 1.3840 - val_accuracy: 0.5000
# Epoch 16/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5392 - accuracy: 0.8472 - val_loss: 1.3459 - val_accuracy: 0.5000
# Epoch 17/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.5854 - accuracy: 0.7708 - val_loss: 1.3083 - val_accuracy: 0.5000
# Epoch 18/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4749 - accuracy: 0.9097 - val_loss: 1.2750 - val_accuracy: 0.5000
# Epoch 19/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.5137 - accuracy: 0.8819 - val_loss: 1.2474 - val_accuracy: 0.5833
# Epoch 20/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4279 - accuracy: 0.8750 - val_loss: 1.2233 - val_accuracy: 0.5833
# Epoch 21/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3947 - accuracy: 0.8750 - val_loss: 1.2018 - val_accuracy: 0.5833
# Epoch 22/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.4181 - accuracy: 0.9132 - val_loss: 1.1840 - val_accuracy: 0.5833
# Epoch 23/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.3663 - accuracy: 0.8993 - val_loss: 1.1672 - val_accuracy: 0.5833
# Epoch 24/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.4389 - accuracy: 0.9028 - val_loss: 1.1516 - val_accuracy: 0.5833
# Epoch 25/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.3181 - accuracy: 0.9757 - val_loss: 1.1377 - val_accuracy: 0.5833
# Epoch 26/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2818 - accuracy: 1.0000 - val_loss: 1.1262 - val_accuracy: 0.5833
# Epoch 27/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.2569 - accuracy: 0.9722 - val_loss: 1.1160 - val_accuracy: 0.5833
# Epoch 28/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2907 - accuracy: 0.9722 - val_loss: 1.1081 - val_accuracy: 0.5833
# Epoch 29/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.2790 - accuracy: 0.9514 - val_loss: 1.0998 - val_accuracy: 0.5833
# Epoch 30/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.3242 - accuracy: 0.9236 - val_loss: 1.0911 - val_accuracy: 0.5833
# Epoch 31/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3405 - accuracy: 0.9375 - val_loss: 1.0797 - val_accuracy: 0.5833
# Epoch 32/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.2232 - accuracy: 0.9722 - val_loss: 1.0688 - val_accuracy: 0.5833
# Epoch 33/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.2322 - accuracy: 0.9861 - val_loss: 1.0554 - val_accuracy: 0.5833
# Epoch 34/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.2487 - accuracy: 0.9132 - val_loss: 1.0416 - val_accuracy: 0.5833
# Epoch 35/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.2373 - accuracy: 0.9097 - val_loss: 1.0289 - val_accuracy: 0.5833
# Epoch 36/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.2493 - accuracy: 0.9514 - val_loss: 1.0152 - val_accuracy: 0.5833
# Epoch 37/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.2493 - accuracy: 0.9757 - val_loss: 1.0006 - val_accuracy: 0.5833
# Epoch 38/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1907 - accuracy: 1.0000 - val_loss: 0.9867 - val_accuracy: 0.5833
# Epoch 39/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1683 - accuracy: 1.0000 - val_loss: 0.9743 - val_accuracy: 0.5833
# Epoch 40/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1583 - accuracy: 0.9757 - val_loss: 0.9633 - val_accuracy: 0.5833
# Epoch 41/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1430 - accuracy: 0.9757 - val_loss: 0.9529 - val_accuracy: 0.5833
# Epoch 42/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1101 - accuracy: 1.0000 - val_loss: 0.9435 - val_accuracy: 0.5833
# Epoch 43/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.2032 - accuracy: 0.9375 - val_loss: 0.9354 - val_accuracy: 0.5833
# Epoch 44/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1264 - accuracy: 1.0000 - val_loss: 0.9269 - val_accuracy: 0.5833
# Epoch 45/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1322 - accuracy: 0.9757 - val_loss: 0.9182 - val_accuracy: 0.5833
# Epoch 46/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1115 - accuracy: 0.9861 - val_loss: 0.9107 - val_accuracy: 0.5833
# Epoch 47/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1246 - accuracy: 0.9757 - val_loss: 0.9015 - val_accuracy: 0.5833
# Epoch 48/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1086 - accuracy: 1.0000 - val_loss: 0.8927 - val_accuracy: 0.5833
# Epoch 49/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1079 - accuracy: 0.9861 - val_loss: 0.8835 - val_accuracy: 0.5833
# Epoch 50/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1476 - accuracy: 0.9757 - val_loss: 0.8766 - val_accuracy: 0.5833
# Epoch 51/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.8707 - val_accuracy: 0.5833
# Epoch 52/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0957 - accuracy: 0.9861 - val_loss: 0.8655 - val_accuracy: 0.5833
# Epoch 53/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.8611 - val_accuracy: 0.5833
# Epoch 54/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1140 - accuracy: 1.0000 - val_loss: 0.8570 - val_accuracy: 0.5833
# Epoch 55/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 0.8525 - val_accuracy: 0.5833
# Epoch 56/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.8478 - val_accuracy: 0.5833
# Epoch 57/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0991 - accuracy: 1.0000 - val_loss: 0.8427 - val_accuracy: 0.5833
# Epoch 58/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 0.8380 - val_accuracy: 0.5833
# Epoch 59/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.8326 - val_accuracy: 0.5833
# Epoch 60/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1000 - accuracy: 1.0000 - val_loss: 0.8276 - val_accuracy: 0.6667
# Epoch 61/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1082 - accuracy: 0.9757 - val_loss: 0.8227 - val_accuracy: 0.6667
# Epoch 62/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.8172 - val_accuracy: 0.6667
# Epoch 63/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 0.8117 - val_accuracy: 0.6667
# Epoch 64/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0978 - accuracy: 1.0000 - val_loss: 0.8066 - val_accuracy: 0.6667
# Epoch 65/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 0.8003 - val_accuracy: 0.6667
# Epoch 66/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.7951 - val_accuracy: 0.6667
# Epoch 67/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 0.7902 - val_accuracy: 0.6667
# Epoch 68/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.7847 - val_accuracy: 0.6667
# Epoch 69/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.7791 - val_accuracy: 0.6667
# Epoch 70/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.7717 - val_accuracy: 0.6667
# Epoch 71/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.7630 - val_accuracy: 0.6667
# Epoch 72/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.7543 - val_accuracy: 0.6667
# Epoch 73/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.7464 - val_accuracy: 0.6667
# Epoch 74/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0650 - accuracy: 1.0000 - val_loss: 0.7377 - val_accuracy: 0.6667
# Epoch 75/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0780 - accuracy: 0.9757 - val_loss: 0.7324 - val_accuracy: 0.6667
# Epoch 76/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0812 - accuracy: 0.9757 - val_loss: 0.7276 - val_accuracy: 0.6667
# Epoch 77/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0573 - accuracy: 1.0000 - val_loss: 0.7213 - val_accuracy: 0.6667
# Epoch 78/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.7159 - val_accuracy: 0.6667
# Epoch 79/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1016 - accuracy: 0.9757 - val_loss: 0.7114 - val_accuracy: 0.6667
# Epoch 80/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 0.7060 - val_accuracy: 0.6667
# Epoch 81/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.7010 - val_accuracy: 0.6667
# Epoch 82/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0399 - accuracy: 1.0000 - val_loss: 0.6961 - val_accuracy: 0.6667
# Epoch 83/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.6667
# Epoch 84/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0488 - accuracy: 0.9757 - val_loss: 0.6878 - val_accuracy: 0.6667
# Epoch 85/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.6826 - val_accuracy: 0.6667
# Epoch 86/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.6776 - val_accuracy: 0.6667
# Epoch 87/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.6727 - val_accuracy: 0.6667
# Epoch 88/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.6681 - val_accuracy: 0.6667
# Epoch 89/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.7500
# Epoch 90/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 0.7500
# Epoch 91/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0771 - accuracy: 0.9757 - val_loss: 0.6507 - val_accuracy: 0.7500
# Epoch 92/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.6467 - val_accuracy: 0.7500
# Epoch 93/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.6414 - val_accuracy: 0.7500
# Epoch 94/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0497 - accuracy: 0.9757 - val_loss: 0.6373 - val_accuracy: 0.7500
# Epoch 95/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0519 - accuracy: 0.9861 - val_loss: 0.6333 - val_accuracy: 0.7500
# Epoch 96/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.6290 - val_accuracy: 0.7500
# Epoch 97/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.6257 - val_accuracy: 0.7500
# Epoch 98/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0535 - accuracy: 1.0000 - val_loss: 0.6223 - val_accuracy: 0.7500
# Epoch 99/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.6191 - val_accuracy: 0.7500
# Epoch 100/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.6148 - val_accuracy: 0.7500
# Epoch 101/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 0.6109 - val_accuracy: 0.7500
# Epoch 102/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.6066 - val_accuracy: 0.7500
# Epoch 103/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.6017 - val_accuracy: 0.7500
# Epoch 104/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.5968 - val_accuracy: 0.7500
# Epoch 105/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.5920 - val_accuracy: 0.7500
# Epoch 106/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.5877 - val_accuracy: 0.7500
# Epoch 107/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.5839 - val_accuracy: 0.8333
# Epoch 108/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.5802 - val_accuracy: 0.8333
# Epoch 109/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.5768 - val_accuracy: 0.8333
# Epoch 110/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.8333
# Epoch 111/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.5667 - val_accuracy: 0.8333
# Epoch 112/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.5622 - val_accuracy: 0.8333
# Epoch 113/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.5572 - val_accuracy: 0.8333
# Epoch 114/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.5549 - val_accuracy: 0.8333
# Epoch 115/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.5515 - val_accuracy: 0.8333
# Epoch 116/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8333
# Epoch 117/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 0.8333
# Epoch 118/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8333
# Epoch 119/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.5400 - val_accuracy: 0.8333
# Epoch 120/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.5376 - val_accuracy: 0.8333
# Epoch 121/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8333
# Epoch 122/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.8333
# Epoch 123/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.5307 - val_accuracy: 0.8333
# Epoch 124/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.5288 - val_accuracy: 0.8333
# Epoch 125/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.8333
# Epoch 126/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.5248 - val_accuracy: 0.8333
# Epoch 127/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.5237 - val_accuracy: 0.8333
# Epoch 128/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.5224 - val_accuracy: 0.8333
# Epoch 129/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.8333
# Epoch 130/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.8333
# Epoch 131/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8333
# Epoch 132/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8333
# Epoch 133/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8333
# Epoch 134/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.8333
# Epoch 135/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.8333
# Epoch 136/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.5123 - val_accuracy: 0.8333
# Epoch 137/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.8333
# Epoch 138/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8333
# Epoch 139/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.8333
# Epoch 140/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.8333
# Epoch 141/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.8333
# Epoch 142/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.8333
# Epoch 143/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8333
# Epoch 144/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.4937 - val_accuracy: 0.8333
# Epoch 145/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.4912 - val_accuracy: 0.8333
# Epoch 146/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.4893 - val_accuracy: 0.8333
# Epoch 147/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.8333
# Epoch 148/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.8333
# Epoch 149/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.8333
# Epoch 150/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.4769 - val_accuracy: 0.8333
# Epoch 151/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.4717 - val_accuracy: 0.8333
# Epoch 152/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.8333
# Epoch 153/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.4645 - val_accuracy: 0.8333
# Epoch 154/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.8333
# Epoch 155/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.8333
# Epoch 156/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4580 - val_accuracy: 0.8333
# Epoch 157/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.4571 - val_accuracy: 0.8333
# Epoch 158/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.4548 - val_accuracy: 0.8333
# Epoch 159/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.8333
# Epoch 160/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.8333
# Epoch 161/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.8333
# Epoch 162/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8333
# Epoch 163/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4463 - val_accuracy: 0.8333
# Epoch 164/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.4447 - val_accuracy: 0.8333
# Epoch 165/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4438 - val_accuracy: 0.8333
# Epoch 166/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.4421 - val_accuracy: 0.8333
# Epoch 167/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4396 - val_accuracy: 0.8333
# Epoch 168/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.8333
# Epoch 169/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.8333
# Epoch 170/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.8333
# Epoch 171/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4364 - val_accuracy: 0.8333
# Epoch 172/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.8333
# Epoch 173/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4360 - val_accuracy: 0.8333
# Epoch 174/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.8333
# Epoch 175/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.8333
# Epoch 176/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0.8333
# Epoch 177/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.4334 - val_accuracy: 0.8333
# Epoch 178/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.8333
# Epoch 179/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.4324 - val_accuracy: 0.8333
# Epoch 180/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.8333
# Epoch 181/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.4265 - val_accuracy: 0.8333
# Epoch 182/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4241 - val_accuracy: 0.8333
# Epoch 183/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.4215 - val_accuracy: 0.8333
# Epoch 184/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4197 - val_accuracy: 0.8333
# Epoch 185/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.4191 - val_accuracy: 0.8333
# Epoch 186/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.8333
# Epoch 187/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4146 - val_accuracy: 0.8333
# Epoch 188/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.8333
# Epoch 189/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.8333
# Epoch 190/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.4137 - val_accuracy: 0.8333
# Epoch 191/200
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.8333
# Epoch 192/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.8333
# Epoch 193/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4128 - val_accuracy: 0.8333
# Epoch 194/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.8333
# Epoch 195/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.8333
# Epoch 196/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4133 - val_accuracy: 0.8333
# Epoch 197/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.4131 - val_accuracy: 0.8333
# Epoch 198/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.8333
# Epoch 199/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8333
# Epoch 200/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.8333
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1572 - accuracy: 0.9000
#
#
#  - Accuracy on un-seen test set: 0.900

# %%
## 5. Evaluate the model on unseen test set
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=0) 
print("- Accuracy on un-seen test set: {0:.3f}".format(test_accuracy))
# Out:
# - Accuracy on un-seen test set: 0.900

# %%
def predict(model, X, y):
    
    # For prediction we need 4 D so need to add the sample number as 1st dim.
    # X -> (1, 130, 13, 1) where the 1st dim is the sample size = 1
    X = X[np.newaxis, ...]
    
    # Get "predictions", which is an array of probablities [[0.37, 0.11, 0.87, ...]]
    prediction = model.predict(X)
    
    # Extract index with max. value
    predicted_index = np.argmax(prediction, axis=1)

    # Get semantaic labels (i.e. text genre labels)
    mapping = load_mappings(JSON_DATA_FILE)
    
    # Map indexes to genre labels
    expected_genre_label = mapping[y]
    predicted_genre_label = mapping[predicted_index][0]
    
    print("Expected genre: '{}'. Predicted genre: '{}'".format(expected_genre_label, predicted_genre_label))

# %%
import random

## 6. Predict
sample = random.randint(0,19) # Total 20 samples, so select any sample 1-20
X = X_test[sample] 
y = y_test[sample]

predict(model, X, y)
# Out:
# Expected genre: 'classical'. Predicted genre: 'classical'

# %%
## 7. Plot training curves - NO regularization
plot_history(history, regularization_flag=True)
