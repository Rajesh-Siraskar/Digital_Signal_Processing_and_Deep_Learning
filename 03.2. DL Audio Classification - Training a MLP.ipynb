# %% [markdown]
# # Deep Learning from Audio Signals
#
# ### Training a MLP on MFCC features generated from Genre music files
#
# Rajesh Siraskar | 03-May-2021
#
# - Load data
# - Split into train/test
# - Build MLP network architecture
# - Compile network
# - Train network

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
# DATA_PATH = "audio_files/genres_REDUCED/"
JSON_FILE = "audio_files/mfcc_json.json"
NUMBER_OF_CLASSES = 4 # Reduced set has only 4 genres

# %%
def load_data (json_file):
    with open(json_file, "r") as fp:
        data = json.load(fp)
        
        # Note: mfcc was converted from a numpy array to list before storing in JSON
        #  Need convert back to numpy array
        X = np.array(data["mfcc"])
        y = np.array(data["labels"])
        
    return X, y

# %%
def plot_history (history, regularization_flag=False):

    fig, axs = plt.subplots(2, figsize=(12, 8)) # width, height
    
    # Accuracy sub-plot
    axs[0].plot(history.history["accuracy"], label="Training accuracy")
    axs[0].plot(history.history["val_accuracy"], label="Test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_facecolor('#FFFFF0') # little darker biege: #F5F5DC
    if regularization_flag: axs[0].set_title("Accuracy plot (with regularizatiton)")
    else: axs[0].set_title("Accuracy plot")
    
    # Error (loss) sub-plot
    axs[1].plot(history.history["loss"], label="Training error")
    axs[1].plot(history.history["val_loss"], label="Test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epochs")   
    axs[1].legend(loc="upper right")
    axs[1].set_facecolor('#FFFFF0')
    if regularization_flag: axs[1].set_title("Error plot (with regularizatiton)")
    else: axs[1].set_title("Error plot")
    

    plt.show()

# %% [markdown]
# ### Main function
# - Network:
#     - 1 input  = Flatten 3-D numpy array and use only 2-Ds (mfcc and hop-length)
#     - 3 hidden = 512 x 256 x 64. Activation = ReLU
#     - 1 output = Number of classes (genres). 4 genres. Activation = softmax
# - Mini-batch
# - Adam optimization
# - Learning-rate=0.0001

# %%
### 1. Load data
X, y = load_data (json_file = JSON_FILE)


### 2. Split into train/test
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3)

### 3. Build MLP network architecture
#     i/p, 3 hidden, o/p and all fully-connected (i.e. dense)
model = keras.Sequential([
    # Input layer: 
    #   input json is a 3D file: We ignore 1st dim and consider only 2nd and 3rd dims
    #   MFCC for each segment, and each mfcc is a vector over an interval = hop-length
    #   - dimension 1: num_segments x n_classes x .wav-files-per-class 
    #   - dimension 2: num_mfcc_vectors_per_segment = math.ceil(samples_per_segment/hop_length)
    #   - dimension 3: num_mfcc
    #   X.shape[1] = dim-2 and X.shape[2]=dim-2
    #   first-dim: interval = inputs.shape[1]
    #   second-dim: mfcc = inputs.shape[2]
    #   NOTE: inputs.shape[0] is the segment number and we are not passing that
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),
    
    # 1st hidden-layer:
    #   Use ReLU instead of sigmoid. Much faster.
    #   ReLU better convergence. Reduce likelihood of vanishing gradients
    #   Vanishing gradients: Multiply error by derivative of activation fn.
    #   Sigmoid fn. derivative = 0.25. Keep multiplying by 0.25, gradient becomes smaller and smaller
    #   and *vanishes*
    keras.layers.Dense(512, activation="relu"),
    
    # 2nd hidden-layer:
    keras.layers.Dense(256, activation="relu"),
    
    # 3rd hidden-layer:
    keras.layers.Dense(64, activation="relu"),
    
    # Output layer: NUMBER_OF_CLASSES = number of genres = 4
    #   activation fn. = softmax for normalizing prob. sum to 1.0 and enables us to pick max. prob.
    keras.layers.Dense(NUMBER_OF_CLASSES,  activation="softmax")
])


### 4. Compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, 
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

model.summary()

## 5. Train network. 
#     Use min-batch. Other techniques
#     (1) Stochastic = Gradient on one sample, fast, inaccurate. 
#     (2) Full training set: Very accurate 
#     (3) Mini-batch: in-between

history = model.fit(X_train, y_train,                 # Training data
                    validation_data=(X_test, y_test), # Test data
                    epochs=50,
                    batch_size=32)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1690)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               865792
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,013,828
# Trainable params: 1,013,828
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2/2 [==============================] - 3s 2s/step - loss: 43.2371 - accuracy: 0.3170 - val_loss: 35.4669 - val_accuracy: 0.2083
# Epoch 2/50
# 2/2 [==============================] - 0s 57ms/step - loss: 23.7942 - accuracy: 0.2396 - val_loss: 12.7425 - val_accuracy: 0.4167
# Epoch 3/50
# 2/2 [==============================] - 0s 58ms/step - loss: 4.1516 - accuracy: 0.6830 - val_loss: 8.3999 - val_accuracy: 0.4583
# Epoch 4/50
# 2/2 [==============================] - 0s 57ms/step - loss: 6.4550 - accuracy: 0.6488 - val_loss: 8.0345 - val_accuracy: 0.5417
# Epoch 5/50
# 2/2 [==============================] - 0s 51ms/step - loss: 3.0566 - accuracy: 0.7530 - val_loss: 7.4761 - val_accuracy: 0.5833
# Epoch 6/50
# 2/2 [==============================] - 0s 54ms/step - loss: 1.1834 - accuracy: 0.9211 - val_loss: 7.2799 - val_accuracy: 0.6250
# Epoch 7/50
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6102 - accuracy: 0.9330 - val_loss: 8.1060 - val_accuracy: 0.6250
# Epoch 8/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0985 - accuracy: 0.9762 - val_loss: 8.4411 - val_accuracy: 0.6250
# Epoch 9/50
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0642 - accuracy: 0.9554 - val_loss: 7.8643 - val_accuracy: 0.6250
# Epoch 10/50
# 2/2 [==============================] - 0s 55ms/step - loss: 2.8328e-05 - accuracy: 1.0000 - val_loss: 7.2639 - val_accuracy: 0.6250
# Epoch 11/50
# 2/2 [==============================] - 0s 48ms/step - loss: 9.3748e-06 - accuracy: 1.0000 - val_loss: 6.7930 - val_accuracy: 0.6250
# Epoch 12/50
# 2/2 [==============================] - 0s 50ms/step - loss: 7.8231e-07 - accuracy: 1.0000 - val_loss: 6.4577 - val_accuracy: 0.6667
# Epoch 13/50
# 2/2 [==============================] - 0s 44ms/step - loss: 2.8702e-07 - accuracy: 1.0000 - val_loss: 6.2263 - val_accuracy: 0.6667
# Epoch 14/50
# 2/2 [==============================] - 0s 50ms/step - loss: 2.7674e-07 - accuracy: 1.0000 - val_loss: 6.0504 - val_accuracy: 0.7083
# Epoch 15/50
# 2/2 [==============================] - 0s 46ms/step - loss: 2.6343e-07 - accuracy: 1.0000 - val_loss: 5.9115 - val_accuracy: 0.7083
# Epoch 16/50
# 2/2 [==============================] - 0s 53ms/step - loss: 3.2108e-07 - accuracy: 1.0000 - val_loss: 5.8024 - val_accuracy: 0.7083
# Epoch 17/50
# 2/2 [==============================] - 0s 58ms/step - loss: 4.6300e-07 - accuracy: 1.0000 - val_loss: 5.7139 - val_accuracy: 0.7083
# Epoch 18/50
# 2/2 [==============================] - 0s 54ms/step - loss: 6.4145e-07 - accuracy: 1.0000 - val_loss: 5.6422 - val_accuracy: 0.7083
# Epoch 19/50
# 2/2 [==============================] - 0s 52ms/step - loss: 8.6886e-07 - accuracy: 1.0000 - val_loss: 5.5845 - val_accuracy: 0.7083
# Epoch 20/50
# 2/2 [==============================] - 0s 49ms/step - loss: 6.7816e-07 - accuracy: 1.0000 - val_loss: 5.5383 - val_accuracy: 0.7083
# Epoch 21/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.4076e-06 - accuracy: 1.0000 - val_loss: 5.5001 - val_accuracy: 0.7500
# Epoch 22/50
# 2/2 [==============================] - 0s 50ms/step - loss: 1.6747e-06 - accuracy: 1.0000 - val_loss: 5.4686 - val_accuracy: 0.7500
# Epoch 23/50
# 2/2 [==============================] - 0s 51ms/step - loss: 1.9571e-06 - accuracy: 1.0000 - val_loss: 5.4443 - val_accuracy: 0.7500
# Epoch 24/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2429e-06 - accuracy: 1.0000 - val_loss: 5.4249 - val_accuracy: 0.7500
# Epoch 25/50
# 2/2 [==============================] - 0s 51ms/step - loss: 2.4399e-06 - accuracy: 1.0000 - val_loss: 5.4088 - val_accuracy: 0.7500
# Epoch 26/50
# 2/2 [==============================] - 0s 52ms/step - loss: 1.4574e-06 - accuracy: 1.0000 - val_loss: 5.3954 - val_accuracy: 0.7500
# Epoch 27/50
# 2/2 [==============================] - 0s 50ms/step - loss: 1.5565e-06 - accuracy: 1.0000 - val_loss: 5.3846 - val_accuracy: 0.7500
# Epoch 28/50
# 2/2 [==============================] - 0s 67ms/step - loss: 1.6163e-06 - accuracy: 1.0000 - val_loss: 5.3760 - val_accuracy: 0.7500
# Epoch 29/50
# 2/2 [==============================] - 0s 58ms/step - loss: 1.6857e-06 - accuracy: 1.0000 - val_loss: 5.3690 - val_accuracy: 0.7500
# Epoch 30/50
# 2/2 [==============================] - 0s 57ms/step - loss: 1.7199e-06 - accuracy: 1.0000 - val_loss: 5.3629 - val_accuracy: 0.7500
# Epoch 31/50
# 2/2 [==============================] - 0s 63ms/step - loss: 1.7525e-06 - accuracy: 1.0000 - val_loss: 5.3577 - val_accuracy: 0.7500
# Epoch 32/50
# 2/2 [==============================] - 0s 59ms/step - loss: 1.7880e-06 - accuracy: 1.0000 - val_loss: 5.3535 - val_accuracy: 0.7500
# Epoch 33/50
# 2/2 [==============================] - 0s 56ms/step - loss: 3.3499e-06 - accuracy: 1.0000 - val_loss: 5.3501 - val_accuracy: 0.7500
# Epoch 34/50
# 2/2 [==============================] - 0s 62ms/step - loss: 3.3738e-06 - accuracy: 1.0000 - val_loss: 5.3474 - val_accuracy: 0.7500
# Epoch 35/50
# 2/2 [==============================] - 0s 76ms/step - loss: 3.3772e-06 - accuracy: 1.0000 - val_loss: 5.3453 - val_accuracy: 0.7500
# Epoch 36/50
# 2/2 [==============================] - 0s 68ms/step - loss: 1.8192e-06 - accuracy: 1.0000 - val_loss: 5.3435 - val_accuracy: 0.7500
# Epoch 37/50
# 2/2 [==============================] - 0s 67ms/step - loss: 1.8079e-06 - accuracy: 1.0000 - val_loss: 5.3421 - val_accuracy: 0.7500
# Epoch 38/50
# 2/2 [==============================] - 0s 67ms/step - loss: 3.3718e-06 - accuracy: 1.0000 - val_loss: 5.3411 - val_accuracy: 0.7500
# Epoch 39/50
# 2/2 [==============================] - 0s 52ms/step - loss: 3.3658e-06 - accuracy: 1.0000 - val_loss: 5.3403 - val_accuracy: 0.7500
# Epoch 40/50
# 2/2 [==============================] - 0s 57ms/step - loss: 1.7894e-06 - accuracy: 1.0000 - val_loss: 5.3397 - val_accuracy: 0.7500
# Epoch 41/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7667e-06 - accuracy: 1.0000 - val_loss: 5.3393 - val_accuracy: 0.7500
# Epoch 42/50
# 2/2 [==============================] - 0s 53ms/step - loss: 3.2993e-06 - accuracy: 1.0000 - val_loss: 5.3390 - val_accuracy: 0.7500
# Epoch 43/50
# 2/2 [==============================] - 0s 52ms/step - loss: 1.7369e-06 - accuracy: 1.0000 - val_loss: 5.3388 - val_accuracy: 0.7500
# Epoch 44/50
# 2/2 [==============================] - 0s 67ms/step - loss: 3.2308e-06 - accuracy: 1.0000 - val_loss: 5.3387 - val_accuracy: 0.7500
# Epoch 45/50
# 2/2 [==============================] - 0s 37ms/step - loss: 1.7029e-06 - accuracy: 1.0000 - val_loss: 5.3387 - val_accuracy: 0.7500
# Epoch 46/50
# 2/2 [==============================] - 0s 65ms/step - loss: 3.1769e-06 - accuracy: 1.0000 - val_loss: 5.3388 - val_accuracy: 0.7500
# Epoch 47/50
# 2/2 [==============================] - 0s 95ms/step - loss: 3.1397e-06 - accuracy: 1.0000 - val_loss: 5.3390 - val_accuracy: 0.7500
# Epoch 48/50
# 2/2 [==============================] - 0s 59ms/step - loss: 1.6348e-06 - accuracy: 1.0000 - val_loss: 5.3391 - val_accuracy: 0.7500
# Epoch 49/50
# 2/2 [==============================] - 0s 44ms/step - loss: 3.0260e-06 - accuracy: 1.0000 - val_loss: 5.3394 - val_accuracy: 0.7500
# Epoch 50/50
# 2/2 [==============================] - 0s 44ms/step - loss: 1.5752e-06 - accuracy: 1.0000 - val_loss: 5.3397 - val_accuracy: 0.7500

# %%
## 6. Plot training curves - NO regularization
plot_history(history, regularization_flag=False)

# %% [markdown]
# ### Reducing Over-fitting
# - 5 techniques
#     - Simpler architecture
#     - Data-augmentation: Pitch change, Time-stretching, Add noise
#     - Early stopping
#     - Drop-out
#     - Regularization
#
# - **Drop-out**: NN can't depend on any particular neuron and tries to spread out weights and makes ot robust
# - **Regularization**:
#     - Add penalty to error function
#     - Punish large weigths
#     - L1: Minimize absolute values of weights: $E(p, y) = \frac{1}{2} (p-y)^2 + \lambda \sum |W_i|$
#     - L2: Minimize _squared_ values of weights: $E(p, y) = \frac{1}{2} (p-y)^2 + \lambda \sum |W_i|^2$
#     - L1: Robust to outliers, simpler model
#     - L2: NOT robust to outliers, learns complex patterns

# %%
### 1. Load data
X, y = load_data (json_file = JSON_FILE)


### 2. Split into train/test
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3)

### 3. Build MLP network architecture
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),
    
    # Hidden-layers: With added Dropout amd Regularization with Lambda=0.001
    # 1st hidden-layer:
    keras.layers.Dense(512, activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    
    # 2nd hidden-layer:
    keras.layers.Dense(256, activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    
    # 3rd hidden-layer:
    keras.layers.Dense(64, activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),
    
    # Output layer: NUMBER_OF_CLASSES = number of genres = 4
    #   activation fn. = softmax for normalizing prob. sum to 1.0 and enables us to pick max. prob.
    keras.layers.Dense(NUMBER_OF_CLASSES,  activation="softmax")
])


### 4. Compile network
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, 
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

model.summary()

## 5. Train network. 
#     Use min-batch. Other techniques
#     (1) Stochastic = Gradient on one sample, fast, inaccurate. 
#     (2) Full training set: Very accurate 
#     (3) Mini-batch: in-between

history_reg = model.fit(X_train, y_train,                 # Training data
                        validation_data=(X_test, y_test), # Test data
                        epochs=100,
                        batch_size=32)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1690)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               865792
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,013,828
# Trainable params: 1,013,828
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 284ms/step - loss: 77.1797 - accuracy: 0.2381 - val_loss: 39.8148 - val_accuracy: 0.2500
# Epoch 2/100
# 2/2 [==============================] - 0s 42ms/step - loss: 65.4374 - accuracy: 0.1354 - val_loss: 45.9580 - val_accuracy: 0.2500
# Epoch 3/100
# 2/2 [==============================] - 0s 41ms/step - loss: 48.8051 - accuracy: 0.3839 - val_loss: 45.5533 - val_accuracy: 0.2083
# Epoch 4/100
# 2/2 [==============================] - 0s 85ms/step - loss: 31.1746 - accuracy: 0.4866 - val_loss: 43.1690 - val_accuracy: 0.3750
# Epoch 5/100
# 2/2 [==============================] - 0s 82ms/step - loss: 40.2573 - accuracy: 0.3735 - val_loss: 39.1660 - val_accuracy: 0.3750
# Epoch 6/100
# 2/2 [==============================] - 0s 30ms/step - loss: 33.5148 - accuracy: 0.5104 - val_loss: 33.1515 - val_accuracy: 0.4167
# Epoch 7/100
# 2/2 [==============================] - 0s 26ms/step - loss: 22.5373 - accuracy: 0.5670 - val_loss: 27.6782 - val_accuracy: 0.4167
# Epoch 8/100
# 2/2 [==============================] - 0s 36ms/step - loss: 29.2019 - accuracy: 0.4881 - val_loss: 20.6710 - val_accuracy: 0.5000
# Epoch 9/100
# 2/2 [==============================] - 0s 26ms/step - loss: 13.8248 - accuracy: 0.5789 - val_loss: 15.9754 - val_accuracy: 0.5833
# Epoch 10/100
# 2/2 [==============================] - 0s 35ms/step - loss: 24.2897 - accuracy: 0.5446 - val_loss: 13.1090 - val_accuracy: 0.6250
# Epoch 11/100
# 2/2 [==============================] - 0s 38ms/step - loss: 18.7095 - accuracy: 0.5030 - val_loss: 11.1151 - val_accuracy: 0.6667
# Epoch 12/100
# 2/2 [==============================] - 0s 32ms/step - loss: 16.3093 - accuracy: 0.5580 - val_loss: 9.6741 - val_accuracy: 0.6667
# Epoch 13/100
# 2/2 [==============================] - 0s 33ms/step - loss: 17.4995 - accuracy: 0.5699 - val_loss: 8.8937 - val_accuracy: 0.6667
# Epoch 14/100
# 2/2 [==============================] - 0s 28ms/step - loss: 16.2694 - accuracy: 0.6131 - val_loss: 9.1784 - val_accuracy: 0.6250
# Epoch 15/100
# 2/2 [==============================] - 0s 38ms/step - loss: 9.1056 - accuracy: 0.7173 - val_loss: 10.0944 - val_accuracy: 0.6250
# Epoch 16/100
# 2/2 [==============================] - 0s 29ms/step - loss: 13.7367 - accuracy: 0.7589 - val_loss: 11.0654 - val_accuracy: 0.6250
# Epoch 17/100
# 2/2 [==============================] - 0s 38ms/step - loss: 14.1885 - accuracy: 0.7158 - val_loss: 12.1537 - val_accuracy: 0.5833
# Epoch 18/100
# 2/2 [==============================] - 0s 36ms/step - loss: 12.0092 - accuracy: 0.6935 - val_loss: 13.0435 - val_accuracy: 0.5417
# Epoch 19/100
# 2/2 [==============================] - 0s 33ms/step - loss: 10.7165 - accuracy: 0.6384 - val_loss: 12.9523 - val_accuracy: 0.5417
# Epoch 20/100
# 2/2 [==============================] - 0s 39ms/step - loss: 13.3519 - accuracy: 0.6488 - val_loss: 11.2297 - val_accuracy: 0.6250
# Epoch 21/100
# 2/2 [==============================] - 0s 47ms/step - loss: 7.6312 - accuracy: 0.6384 - val_loss: 9.2699 - val_accuracy: 0.6250
# Epoch 22/100
# 2/2 [==============================] - 0s 44ms/step - loss: 4.7864 - accuracy: 0.8065 - val_loss: 7.7227 - val_accuracy: 0.6667
# Epoch 23/100
# 2/2 [==============================] - 0s 32ms/step - loss: 12.1489 - accuracy: 0.6488 - val_loss: 6.9977 - val_accuracy: 0.6667
# Epoch 24/100
# 2/2 [==============================] - 0s 33ms/step - loss: 8.0010 - accuracy: 0.7515 - val_loss: 6.8732 - val_accuracy: 0.6667
# Epoch 25/100
# 2/2 [==============================] - 0s 28ms/step - loss: 7.1754 - accuracy: 0.7604 - val_loss: 7.0051 - val_accuracy: 0.6667
# Epoch 26/100
# 2/2 [==============================] - 0s 35ms/step - loss: 5.3723 - accuracy: 0.7827 - val_loss: 7.3886 - val_accuracy: 0.6667
# Epoch 27/100
# 2/2 [==============================] - 0s 34ms/step - loss: 6.6272 - accuracy: 0.7470 - val_loss: 8.0433 - val_accuracy: 0.6667
# Epoch 28/100
# 2/2 [==============================] - 0s 32ms/step - loss: 6.0638 - accuracy: 0.8408 - val_loss: 8.5475 - val_accuracy: 0.6667
# Epoch 29/100
# 2/2 [==============================] - 0s 41ms/step - loss: 10.3709 - accuracy: 0.6845 - val_loss: 9.2009 - val_accuracy: 0.6250
# Epoch 30/100
# 2/2 [==============================] - 0s 38ms/step - loss: 5.4854 - accuracy: 0.8065 - val_loss: 9.4187 - val_accuracy: 0.6250
# Epoch 31/100
# 2/2 [==============================] - 0s 38ms/step - loss: 5.2275 - accuracy: 0.8289 - val_loss: 9.4405 - val_accuracy: 0.6250
# Epoch 32/100
# 2/2 [==============================] - 0s 48ms/step - loss: 6.7864 - accuracy: 0.7247 - val_loss: 10.3247 - val_accuracy: 0.6250
# Epoch 33/100
# 2/2 [==============================] - 0s 36ms/step - loss: 4.5170 - accuracy: 0.8378 - val_loss: 11.2529 - val_accuracy: 0.6250
# Epoch 34/100
# 2/2 [==============================] - 0s 47ms/step - loss: 4.8435 - accuracy: 0.8512 - val_loss: 11.2660 - val_accuracy: 0.6250
# Epoch 35/100
# 2/2 [==============================] - 0s 38ms/step - loss: 5.9796 - accuracy: 0.8408 - val_loss: 10.9467 - val_accuracy: 0.5833
# Epoch 36/100
# 2/2 [==============================] - 0s 28ms/step - loss: 2.8120 - accuracy: 0.8304 - val_loss: 10.3294 - val_accuracy: 0.5833
# Epoch 37/100
# 2/2 [==============================] - 0s 43ms/step - loss: 2.7061 - accuracy: 0.8631 - val_loss: 9.7884 - val_accuracy: 0.5833
# Epoch 38/100
# 2/2 [==============================] - 0s 39ms/step - loss: 4.7162 - accuracy: 0.7827 - val_loss: 9.3945 - val_accuracy: 0.5833
# Epoch 39/100
# 2/2 [==============================] - 0s 47ms/step - loss: 2.8440 - accuracy: 0.8854 - val_loss: 9.0883 - val_accuracy: 0.6250
# Epoch 40/100
# 2/2 [==============================] - 0s 41ms/step - loss: 5.9186 - accuracy: 0.8259 - val_loss: 8.4833 - val_accuracy: 0.6250
# Epoch 41/100
# 2/2 [==============================] - 0s 29ms/step - loss: 6.9904 - accuracy: 0.8199 - val_loss: 8.1583 - val_accuracy: 0.6667
# Epoch 42/100
# 2/2 [==============================] - 0s 34ms/step - loss: 3.1780 - accuracy: 0.8869 - val_loss: 7.9307 - val_accuracy: 0.6667
# Epoch 43/100
# 2/2 [==============================] - 0s 36ms/step - loss: 2.8634 - accuracy: 0.8750 - val_loss: 7.4827 - val_accuracy: 0.6667
# Epoch 44/100
# 2/2 [==============================] - 0s 34ms/step - loss: 2.8060 - accuracy: 0.8854 - val_loss: 7.1542 - val_accuracy: 0.7083
# Epoch 45/100
# 2/2 [==============================] - 0s 36ms/step - loss: 3.2243 - accuracy: 0.9092 - val_loss: 6.9090 - val_accuracy: 0.7083
# Epoch 46/100
# 2/2 [==============================] - 0s 39ms/step - loss: 4.9235 - accuracy: 0.8869 - val_loss: 6.6408 - val_accuracy: 0.7083
# Epoch 47/100
# 2/2 [==============================] - 0s 29ms/step - loss: 2.3889 - accuracy: 0.8631 - val_loss: 6.3657 - val_accuracy: 0.7500
# Epoch 48/100
# 2/2 [==============================] - 0s 34ms/step - loss: 4.6750 - accuracy: 0.8304 - val_loss: 6.4826 - val_accuracy: 0.7500
# Epoch 49/100
# 2/2 [==============================] - 0s 45ms/step - loss: 5.6283 - accuracy: 0.7738 - val_loss: 7.1005 - val_accuracy: 0.7500
# Epoch 50/100
# 2/2 [==============================] - 0s 46ms/step - loss: 5.9574 - accuracy: 0.8065 - val_loss: 8.9369 - val_accuracy: 0.7083
# Epoch 51/100
# 2/2 [==============================] - 0s 43ms/step - loss: 5.8231 - accuracy: 0.8408 - val_loss: 11.3893 - val_accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 0s 42ms/step - loss: 3.1938 - accuracy: 0.8735 - val_loss: 13.6682 - val_accuracy: 0.6250
# Epoch 53/100
# 2/2 [==============================] - 0s 43ms/step - loss: 3.4328 - accuracy: 0.8988 - val_loss: 15.0488 - val_accuracy: 0.6250
# Epoch 54/100
# 2/2 [==============================] - 0s 41ms/step - loss: 3.3329 - accuracy: 0.8765 - val_loss: 16.0268 - val_accuracy: 0.6250
# Epoch 55/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4958 - accuracy: 0.9315 - val_loss: 16.4756 - val_accuracy: 0.6250
# Epoch 56/100
# 2/2 [==============================] - 0s 42ms/step - loss: 4.3656 - accuracy: 0.8542 - val_loss: 16.0233 - val_accuracy: 0.6250
# Epoch 57/100
# 2/2 [==============================] - 0s 42ms/step - loss: 6.5391 - accuracy: 0.8616 - val_loss: 14.9014 - val_accuracy: 0.5833
# Epoch 58/100
# 2/2 [==============================] - 0s 41ms/step - loss: 2.5212 - accuracy: 0.8988 - val_loss: 12.6368 - val_accuracy: 0.5417
# Epoch 59/100
# 2/2 [==============================] - 0s 43ms/step - loss: 2.9171 - accuracy: 0.9211 - val_loss: 11.0545 - val_accuracy: 0.6250
# Epoch 60/100
# 2/2 [==============================] - 0s 44ms/step - loss: 2.4778 - accuracy: 0.9211 - val_loss: 10.5959 - val_accuracy: 0.6667
# Epoch 61/100
# 2/2 [==============================] - 0s 43ms/step - loss: 3.3642 - accuracy: 0.9211 - val_loss: 10.5429 - val_accuracy: 0.6667
# Epoch 62/100
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4885 - accuracy: 0.9420 - val_loss: 10.6475 - val_accuracy: 0.6667
# Epoch 63/100
# 2/2 [==============================] - 0s 42ms/step - loss: 2.9662 - accuracy: 0.8304 - val_loss: 10.7924 - val_accuracy: 0.6667
# Epoch 64/100
# 2/2 [==============================] - 0s 43ms/step - loss: 3.0710 - accuracy: 0.9182 - val_loss: 10.8602 - val_accuracy: 0.6667
# Epoch 65/100
# 2/2 [==============================] - 0s 33ms/step - loss: 3.9793 - accuracy: 0.8750 - val_loss: 10.8969 - val_accuracy: 0.6667
# Epoch 66/100
# 2/2 [==============================] - 0s 48ms/step - loss: 3.7560 - accuracy: 0.8988 - val_loss: 10.8592 - val_accuracy: 0.7083
# Epoch 67/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.6115 - accuracy: 0.9435 - val_loss: 10.8554 - val_accuracy: 0.7083
# Epoch 68/100
# 2/2 [==============================] - 0s 45ms/step - loss: 2.6897 - accuracy: 0.9196 - val_loss: 10.9552 - val_accuracy: 0.7083
# Epoch 69/100
# 2/2 [==============================] - 0s 42ms/step - loss: 2.2916 - accuracy: 0.9315 - val_loss: 10.9872 - val_accuracy: 0.7083
# Epoch 70/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6486 - accuracy: 0.9658 - val_loss: 11.0169 - val_accuracy: 0.7083
# Epoch 71/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6832 - accuracy: 0.9330 - val_loss: 11.3097 - val_accuracy: 0.6667
# Epoch 72/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2.3809 - accuracy: 0.8973 - val_loss: 11.9426 - val_accuracy: 0.7083
# Epoch 73/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.7541 - accuracy: 0.9658 - val_loss: 12.8080 - val_accuracy: 0.7083
# Epoch 74/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.9521 - accuracy: 0.9539 - val_loss: 13.1963 - val_accuracy: 0.7083
# Epoch 75/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2.2461 - accuracy: 0.9435 - val_loss: 13.2329 - val_accuracy: 0.7083
# Epoch 76/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.5176 - accuracy: 0.9330 - val_loss: 13.2268 - val_accuracy: 0.7083
# Epoch 77/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6634 - accuracy: 0.9777 - val_loss: 12.9073 - val_accuracy: 0.7083
# Epoch 78/100
# 2/2 [==============================] - 0s 50ms/step - loss: 1.8388 - accuracy: 0.9435 - val_loss: 12.5606 - val_accuracy: 0.7083
# Epoch 79/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.5834 - accuracy: 0.9420 - val_loss: 11.9780 - val_accuracy: 0.6667
# Epoch 80/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1.6683 - accuracy: 0.9762 - val_loss: 11.0943 - val_accuracy: 0.6667
# Epoch 81/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.9453 - accuracy: 0.9420 - val_loss: 10.3191 - val_accuracy: 0.7083
# Epoch 82/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.5486 - accuracy: 0.9554 - val_loss: 9.6079 - val_accuracy: 0.7083
# Epoch 83/100
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1392 - accuracy: 0.9196 - val_loss: 9.0368 - val_accuracy: 0.7083
# Epoch 84/100
# 2/2 [==============================] - 0s 49ms/step - loss: 2.1277 - accuracy: 0.9107 - val_loss: 8.6471 - val_accuracy: 0.7083
# Epoch 85/100
# 2/2 [==============================] - 0s 37ms/step - loss: 3.2051 - accuracy: 0.8973 - val_loss: 8.2371 - val_accuracy: 0.7083
# Epoch 86/100
# 2/2 [==============================] - 0s 67ms/step - loss: 2.2434 - accuracy: 0.9539 - val_loss: 8.0418 - val_accuracy: 0.7083
# Epoch 87/100
# 2/2 [==============================] - 0s 52ms/step - loss: 2.8157 - accuracy: 0.9211 - val_loss: 8.2443 - val_accuracy: 0.7083
# Epoch 88/100
# 2/2 [==============================] - 0s 49ms/step - loss: 4.2788 - accuracy: 0.8973 - val_loss: 8.2863 - val_accuracy: 0.7083
# Epoch 89/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1.7134 - accuracy: 0.9777 - val_loss: 8.4182 - val_accuracy: 0.7083
# Epoch 90/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.3498 - accuracy: 0.9762 - val_loss: 8.4505 - val_accuracy: 0.7083
# Epoch 91/100
# 2/2 [==============================] - 0s 42ms/step - loss: 3.2120 - accuracy: 0.9107 - val_loss: 8.2163 - val_accuracy: 0.7500
# Epoch 92/100
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4968 - accuracy: 0.9211 - val_loss: 8.0138 - val_accuracy: 0.7500
# Epoch 93/100
# 2/2 [==============================] - 0s 43ms/step - loss: 2.2728 - accuracy: 0.9658 - val_loss: 8.1536 - val_accuracy: 0.7500
# Epoch 94/100
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4638 - accuracy: 0.9196 - val_loss: 8.3838 - val_accuracy: 0.7500
# Epoch 95/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.1711 - accuracy: 1.0000 - val_loss: 8.5792 - val_accuracy: 0.7500
# Epoch 96/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1.4564 - accuracy: 0.9554 - val_loss: 8.9535 - val_accuracy: 0.7500
# Epoch 97/100
# 2/2 [==============================] - 0s 36ms/step - loss: 3.0026 - accuracy: 0.9211 - val_loss: 9.0834 - val_accuracy: 0.7500
# Epoch 98/100
# 2/2 [==============================] - 0s 26ms/step - loss: 2.1371 - accuracy: 0.9554 - val_loss: 9.0810 - val_accuracy: 0.7500
# Epoch 99/100
# 2/2 [==============================] - 0s 33ms/step - loss: 1.4197 - accuracy: 0.9777 - val_loss: 9.0186 - val_accuracy: 0.7500
# Epoch 100/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.8679 - accuracy: 0.9315 - val_loss: 8.8429 - val_accuracy: 0.7500

# %%
## 6. Plot training curves - With drop-out and L2 regularization
plot_history(history_reg, regularization_flag=True)
